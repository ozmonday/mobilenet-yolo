# %%
import json
import os
import sys  
sys.path.insert(0, '..')
import models
import numpy as np

from tensorflow.keras import layers
from mobilenetyolo import MNetYolo

# %%
weight_path = os.path.join('..', 'assets', 'new2-model-mobilenet-yolo-resume.159-107.74.h5')
val_notation = os.path.join('..', 'assets', 'validation.txt')
train_notation = os.path.join('..', 'assets', 'training.txt')
class_name = os.path.join('..', 'assets', 'class_name.txt')

# %%
config = {
  'image_size' : (608, 608, 3),
  'anchors' : [5, 8, 15, 28, 37, 61, 80, 125, 159, 230],
  'stride' : 32,
  'xyscale': 1.05,

  # Training
  'iou_loss_thresh': 0.5,
  'batch_size': 8,
  'num_gpu': 1,  # 2,

  # Inference
  'max_boxes': 100,
  'iou_threshold': 0.413,
  'score_threshold': 0.3,
}

# %%
model = MNetYolo(config, class_name, weight_path)
# Out:
# 2021-12-15 20:14:27.609009: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-12-15 20:14:27.609073: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ozmonday): /proc/driver/nvidia/version does not exist
# 2021-12-15 20:14:27.610079: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (None, 76, 76, 256)
# (None, 38, 38, 512)
# (None, 19, 19, 1024)
# load from ../assets/new2-model-mobilenet-yolo-resume.159-107.74.h5
# 5

# %%
model.predict('../test_img/23_Shoppers_Shoppers_23_32.jpg')
